# %%
import pandas as pd

data = pd.read_csv("/home/yash/Desktop/MORSHI_Audit_Checklist_Pending.csv")

# %%
data
# Out:
#     District   Block         Village  \
# 0   AMRAVATI  MORSHI  YASHWANT NAGAR
# 1   AMRAVATI  MORSHI  YASHWANT NAGAR
# 2   AMRAVATI  MORSHI          AMBADA
# 3   AMRAVATI  MORSHI         RITHPUR
# 4   AMRAVATI  MORSHI        SHIRKHED
# 5   AMRAVATI  MORSHI        SHIRKHED
# 6   AMRAVATI  MORSHI      NERPINGALI
# 7   AMRAVATI  MORSHI     PIMPALKHUTA
# 8   AMRAVATI  MORSHI       PORGAVHAN
# 9   AMRAVATI  MORSHI       PORGAVHAN
# 10  AMRAVATI  MORSHI       PORGAVHAN
# 11  AMRAVATI  MORSHI       PORGAVHAN
# 12  AMRAVATI  MORSHI       PORGAVHAN
# 13  AMRAVATI  MORSHI       MORSHI NP
#
#                                        School        udise  \
# 0              Z P UPPER PRIMARY  SCHOOL PALA  27071100801
# 1         Z P UPPER PRIMARY  SCHOOL BHIVKUNDI  27071100401
# 2          Z P PRIMARY MARATHI SCHOOL DAHASUR  27071102201
# 3            ABASAHEB KHEDKAR HIGHSCHOOL KEHD  27071103503
# 4         Z P  PRIMARY MARATHI SCHOOL, NIMBHI  27071106501
# ...

# %%
data['School']
# Out:
# 0                Z P UPPER PRIMARY  SCHOOL PALA
# 1           Z P UPPER PRIMARY  SCHOOL BHIVKUNDI
# 2            Z P PRIMARY MARATHI SCHOOL DAHASUR
# 3              ABASAHEB KHEDKAR HIGHSCHOOL KEHD
# 4           Z P  PRIMARY MARATHI SCHOOL, NIMBHI
# 5             Z P PRIMARY MARATHI SCHOOL  ASONA
# 6             Z P PRIMARY MARATHI SCHOOL SHIRUR
# 7                  GOPALKRUSHAN VIDYALAYA PARDI
# 8     Z P UPPER PRIMARY MARATHI SCHOOL VISHNORA
# 9         Z P PRIMARY MARATHI SCHOOL KATPUR (M)
# 10           Z P PRIMARY MARATHI SCHOOL DABHERI
# 11       Z P PRIMARY MARATHI SCHOOL BRAMHANWADA
# 12                      LOKMANYA VIDYA VISHNORA
# 13            JIJAMATA GIRLS HIGH SCHOOL MORSHI
# Name: School, dtype: object

# %%
li = [1,2,3,4,5]
a = li.pop(2)
print(li[-a])
# Out:
# 2
